# %%
## 영상용 api 키, 하고 바로 삭제하기
import requests
import re
from dotenv import load_dotenv
import os
import xml.etree.ElementTree as ET
from datetime import datetime
from pprint import pprint
from youtube_transcript_api import YouTubeTranscriptApi

load_dotenv()
YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")
YOUTUBE_API_URL = 'https://www.googleapis.com/youtube/v3'

# %%
def get_youtube_transcript(url: str) -> str:
    """ 유튜브 영상 URL에 대한 자막을 가져옵니다."""
    
    # 1. 유튜브 URL에서 비디오 ID를 추출합니다.
    video_id_match = re.search(r"(?:v=|\/)([0-9A-Za-z_-]{11}).*", url)
    if not video_id_match:
        raise ValueError("유효하지 않은 YouTube URL이 제공되었습니다")
    video_id = video_id_match.group(1)
    
    languages = ["ko", "en"]
    # 2. youtube_transcript_api를 사용하여 자막을 가져옵니다.
    try:
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=languages)
        
        # 3. 자막 목록의 'text' 부분을 하나의 문자열로 결합합니다.
        transcript_text = " ".join([entry["text"] for entry in transcript_list])
        return transcript_text

    except Exception as e:
        raise RuntimeError(f"비디오 ID '{video_id}'에 대한 자막을 찾을 수 없거나 사용할 수 없습니다.{e}")

# %%
transcript = get_youtube_transcript("https://www.youtube.com/watch?v=atXyXP3yYZ4&t=3s") # operator 관련 영상  OpenAI
print(transcript) # "notebook.output.wordWrap": true in settings.json
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/mcp_test/python_mcp_agent/venv/lib/python3.12/site-packages/youtube_transcript_api/_transcripts.py:95, in _raise_http_errors(response, video_id)
#      94 try:
# ---> 95     response.raise_for_status()
#      96     return response
#
# File ~/mcp_test/python_mcp_agent/venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.youtube.com/api/timedtext?v=atXyXP3yYZ4&ei=DZF0aOywEJ2z1d8P48TowA4&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1752494973&sparams=ip,ipbits,expire,v,ei,caps,opi,xoaf&signature=82F97B602C563536B07B9EF9B539996DD5B4D55D.B03975908CE1285EF099DCB7B7EEDB8A7583E743&key=yt8&lang=en
#
# During handling of the above exception, another exception occurred:
#
# YouTubeRequestFailed                      Traceback (most recent call last)
# Cell In[31], line 13, in get_youtube_transcript(url)
#      12 try:
# ---> 13     transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=languages)
#      15     # 3. 자막 목록의 'text' 부분을 하나의 문자열로 결합합니다.
#
# File ~/mcp_test/python_mcp_agent/venv/lib/python3.12/site-packages/youtube_transcript_api/_api.py:283, in YouTubeTranscriptApi.get_transcript(cls, video_id, languages, proxies, preserve_formatting)
#     279 assert isinstance(video_id, str), "`video_id` must be a string"
#     280 return (
#     281     cls.list_transcripts(video_id, proxies)
#     282     .find_transcript(languages)
# --> 283     .fetch(preserve_formatting=preserve_formatting)
#     284     .to_raw_data()
#     285 )
#
# File ~/mcp_test/python_mcp_agent/venv/lib/python3.12/site-packages/youtube_transcript_api/_transcripts.py:137, in Transcript.fetch(self, preserve_formatting)
#     135 response = self._http_client.get(self._url)
#     136 snippets = _TranscriptParser(preserve_formatting=preserve_formatting).parse(
# --> 137     _raise_http_errors(response, self.video_id).text,
#     138 )
#     139 return FetchedTranscript(
#     140     snippets=snippets,
#     141     video_id=self.video_id,
#    (...)    144     is_generated=self.is_generated,
#     145 )
#
# File ~/mcp_test/python_mcp_agent/venv/lib/python3.12/site-packages/youtube_transcript_api/_transcripts.py:98, in _raise_http_errors(response, video_id)
#      97 except HTTPError as error:
# ---> 98     raise YouTubeRequestFailed(video_id, error)
#
# YouTubeRequestFailed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=atXyXP3yYZ4! This is most likely caused by:
#
# Request to YouTube failed: 429 Client Error: Too Many Requests for url: https://www.youtube.com/api/timedtext?v=atXyXP3yYZ4&ei=DZF0aOywEJ2z1d8P48TowA4&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1752494973&sparams=ip,ipbits,expire,v,ei,caps,opi,xoaf&signature=82F97B602C563536B07B9EF9B539996DD5B4D55D.B03975908CE1285EF099DCB7B7EEDB8A7583E743&key=yt8&lang=en
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 transcript = get_youtube_transcript("https://www.youtube.com/watch?v=atXyXP3yYZ4&t=3s") # operator 관련 영상  OpenAI
#       2 print(transcript) # "notebook.output.wordWrap": true in settings.json
#
# Cell In[31], line 20, in get_youtube_transcript(url)
#      17     return transcript_text
#      19 except Exception as e:
# ---> 20     raise RuntimeError(f"비디오 ID '{video_id}'에 대한 자막을 찾을 수 없거나 사용할 수 없습니다.{e}")
#
# RuntimeError: 비디오 ID 'atXyXP3yYZ4'에 대한 자막을 찾을 수 없거나 사용할 수 없습니다.
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=atXyXP3yYZ4! This is most likely caused by:
#
# Request to YouTube failed: 429 Client Error: Too Many Requests for url: https://www.youtube.com/api/timedtext?v=atXyXP3yYZ4&ei=DZF0aOywEJ2z1d8P48TowA4&caps=asr&opi=112496729&xoaf=5&hl=en&ip=0.0.0.0&ipbits=0&expire=1752494973&sparams=ip,ipbits,expire,v,ei,caps,opi,xoaf&signature=82F97B602C563536B07B9EF9B539996DD5B4D55D.B03975908CE1285EF099DCB7B7EEDB8A7583E743&key=yt8&lang=en
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
def search_youtube_videos(query: str) :
    """유튜브에서 특정 키워드로 동영상을 검색하고 세부 정보를 가져옵니다"""
    try:
        # 1. 동영상 검색
        max_results: int = 20
        search_url = f"{YOUTUBE_API_URL}/search?part=snippet&q={requests.utils.quote(query)}&type=video&maxResults={max_results}&key={YOUTUBE_API_KEY}"
        print(f"Searching YouTube with URL: {search_url}")

        search_response = requests.get(search_url)
        search_data = search_response.json()
        video_ids = [item['id']['videoId'] for item in search_data.get('items', [])]

        if not video_ids:
            print("No videos found for the query.")
            return []

        video_details_url = f"{YOUTUBE_API_URL}/videos?part=snippet,statistics&id={','.join(video_ids)}&key={YOUTUBE_API_KEY}"
        print(f"영상 정보 가져오는 중: {video_details_url}")
        details_response = requests.get(video_details_url)
        details_response.raise_for_status()
        details_data = details_response.json()

        videos = []
        for item in details_data.get('items', []):
            snippet = item.get('snippet', {})
            statistics = item.get('statistics', {})
            thumbnails = snippet.get('thumbnails', {})
            high_thumbnail = thumbnails.get('high', {}) 
            view_count = statistics.get('viewCount')
            like_count = statistics.get('likeCount')

            video_card = {
                "title": snippet.get('title', 'N/A'),
                "publishedDate": snippet.get('publishedAt', ''),
                "channelName": snippet.get('channelTitle', 'N/A'),
                "channelId": snippet.get('channelId', ''),
                "thumbnailUrl": high_thumbnail.get('url', ''),
                "viewCount": int(view_count) if view_count is not None else None,
                "likeCount": int(like_count) if like_count is not None else None,
                "url": f"https://www.youtube.com/watch?v={item.get('id', '')}",
            }
            videos.append(video_card)

        if not videos:
            print("No video details could be fetched.")
            return []

        return videos

    except Exception as e:
        print(f"Error: {e}")
        return []

# %%
import os
import openai
from supabase import create_client, Client
import requests
from dotenv import load_dotenv
load_dotenv()
print("SUPABASE_URL:", os.getenv("SUPABASE_URL"))
print("SUPABASE_KEY:", os.getenv("SUPABASE_KEY"))

SUPABASE_URL = "https://qkwqilxmwyethocfzofq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InFrd3FpbHhtd3lldGhvY2Z6b2ZxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTE4NzU4MDEsImV4cCI6MjA2NzQ1MTgwMX0.WqGljJzf5Jt2vY3gHjpa7gQ9JbMqaZ_u3TXM-YIc79g"
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")
YOUTUBE_API_URL = 'https://www.googleapis.com/youtube/v3'

supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)
openai.api_key = OPENAI_API_KEY

def save_youtube_embeddings(query: str) -> str:
    """유튜브에서 query로 100개 영상을 검색해 title 임베딩 후 supabase DB에 id, url, title, embedding을 중복 없이 저장합니다."""
    max_results = 100
    search_url = f"{YOUTUBE_API_URL}/search?part=snippet&q={requests.utils.quote(query)}&type=video&maxResults={max_results}&key={YOUTUBE_API_KEY}"
    search_response = requests.get(search_url)
    search_data = search_response.json()
    video_ids = [item['id']['videoId'] for item in search_data.get('items', [])]
    if not video_ids:
        return "검색 결과가 없습니다."
    video_details_url = f"{YOUTUBE_API_URL}/videos?part=snippet,statistics&id={','.join(video_ids)}&key={YOUTUBE_API_KEY}"
    details_response = requests.get(video_details_url)
    details_response.raise_for_status()
    details_data = details_response.json()
    count = 0
    for item in details_data.get('items', []):
        snippet = item.get('snippet', {})
        video_id = item.get('id', '')
        title = snippet.get('title', 'N/A')
        url = f"https://www.youtube.com/watch?v={video_id}"
        # 임베딩
        try:
            embedding = openai.embeddings.create(
                input=title,
                model="text-embedding-3-small"
            ).data[0].embedding
        except Exception as e:
            print(f"임베딩 실패: {title} - {e}")
            continue
        # supabase 저장
        data = {
            "video_id": video_id,
            "url": url,
            "title": title,
            "embedding": embedding
        }
        try:
            supabase.table("youtube_videos").insert(data).execute()
            count += 1
        except Exception as e:
            print(f"중복 또는 에러: {video_id} - {e}")
            continue
    return f"총 {count}개 영상이 저장되었습니다."
# Out:
# SUPABASE_URL: https://qkwqilxmwyethocfzofq.supabase.co
# SUPABASE_KEY: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InFrd3FpbHhtd3lldGhvY2Z6b2ZxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTE4NzU4MDEsImV4cCI6MjA2NzQ1MTgwMX0.WqGljJzf5Jt2vY3gHjpa7gQ9JbMqaZ_u3TXM-YIc79g

# %%
import requests
import re
import os
from dotenv import load_dotenv
load_dotenv()

YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")
YOUTUBE_API_URL = 'https://www.googleapis.com/youtube/v3'

def get_channel_id_from_video_url(video_url):
    # 유튜브 영상 ID 추출
    video_id_match = re.search(r"(?:v=|/)([0-9A-Za-z_-]{11})", video_url)
    if not video_id_match:
        raise ValueError("유효하지 않은 YouTube URL")
    video_id = video_id_match.group(1)
    # 영상 상세 정보에서 채널 ID 추출
    api_url = f"{YOUTUBE_API_URL}/videos?part=snippet&id={video_id}&key={YOUTUBE_API_KEY}"
    resp = requests.get(api_url)
    data = resp.json()
    channel_id = data['items'][0]['snippet']['channelId']
    return channel_id

def get_channel_videos(channel_id, max_results=100):
    video_ids = []
    next_page_token = ""
    while len(video_ids) < max_results:
        search_url = f"{YOUTUBE_API_URL}/search?part=snippet&channelId={channel_id}&type=video&maxResults=50&key={YOUTUBE_API_KEY}"
        if next_page_token:
            search_url += f"&pageToken={next_page_token}"
        resp = requests.get(search_url)
        data = resp.json()
        for item in data.get('items', []):
            video_ids.append(item['id']['videoId'])
            if len(video_ids) >= max_results:
                break
        next_page_token = data.get('nextPageToken')
        if not next_page_token:
            break
    return video_ids

# 테스트
video_url = "https://www.youtube.com/watch?v=x0u0iKs2Ub4&t=13s"
channel_id = get_channel_id_from_video_url(video_url)
print("채널 ID:", channel_id)
video_ids = get_channel_videos(channel_id, max_results=100)
print("가져온 영상 개수:", len(video_ids))
print("영상 ID 리스트:", video_ids)
# Out:
# 채널 ID: UCyn-K7rZLXjGl7VXGweIlcA
# 가져온 영상 개수: 100
# 영상 ID 리스트: ['XbO68-Jkapk', 'NksEV-moMkA', 'nmLO04GfA0k', '9P1ffccFFiw', 'DdVSrx3cOHU', 'CjTbumZOFcM', 'saBMXFDw9SQ', 'p3lQ2A9H_d0', 'PgIJlbWb7Nc', '9pHwI97IFlU', '__Ztp3nLFiQ', 'Y_H578nbBiA', 'lP7Ioi0Xu1A', 'gKa8TOUN94A', '5nzs_M1lHM8', 'JN3RIv7oniE', '1O1JGpwT7ss', 'Ex12Cj8XGWw', 'CDmTQOFcw9g', '_-oaae1jjWs', 'kb410U8gEZ8', 'xXDfp1fNStg', 'venz1kOiz3c', 'LbUcOufWCKs', 'yOuoqUatqZs', 'MdVhJ2mpxI4', 'tuc_c0H0Yn0', '34BJfQ7fH9g', 'irpwZ-y76Zw', 'BcZ6qYrTqIU', 'opgXYFG-K7Q', 'ufXRm1lqf1g', 'Bxw10weIF0c', 'oIA_mKNnUjE', 'RdOryJj-9cQ', 'DJzHEhpCvbo', 'KburR6QBmgg', '5D-b2NrZoQI', 'DC2IiMN0n48', 'p--HSH666H0', '_ER01aZ3PhM', 'OGSbgTWwm0Y', 'O0qfKTrUetg', '3MmbFkAMgA8', '8WEpKIIiDno', '-MvfUUPB5-Y', 'OyVq1NzxjEM', 'al0_T_mO9rM', 'qWbHSOplcvY', 'iK0dSM4FqVs', '0Kar23fZ0F4', 'Mfnwc1dc0MY', 'p7HGmwiuuvE', 'iNh_bXmYfgw', 'LKiuHdFdLWg', '3ET3nXU--nY', 'tqDMACWbDt4', 'q_qHdJDBw6w', '37-BCf85bHk', 'qMRs_G4Agh0', 'J35CD97lhq0', 'ZYr-Vgn2w-8', 'Q25-6ytLuTE', 'xRONNVN3RCE', 'vG07DHeNH9c', '7zSEQN-VuWw', 'oiqyraiKk_k', 'SeUG8iRDE_g', 'nj-DjQFEZb0', 'VDn_dcC88mc', 'bYQhA06Vgno', 'kfGi3rTct8c', 'eeiqjyYgPew', 'XTwdHX-68F8', '1GWufQQ2Oqg', '3-xgRrEX-sQ', 'WT9tCViPddU', 'sRQxVQ5-NNA', 'j7s9VRsrm9o', 'NtsoIQQXGsA', '_MhD25Ip3bc', 'xexAbSUQzSw', 't4Es8mwdYlE', 'u1m21zlfVLo', 'ffuakdFmuh4', 'wpUsg7f-F4o', '47OIcvpqxlo', '7cCAlN06WPc', '9KtzgdvHYYE', 'SZp5fTHZnmc', 'wfm951HEpGU', 'tCe6B6U8wHw', '78AQ-ten9lE', 'MqdncXPR0lY', 'b9QhRrI_slU', 'fQJCL2cgLRk', 'MWPckCGPcgY', 'RVfSeUZ8XkY', 'e--h7ax_6pQ', 'WneiVYnZgHo']

# %%
import os
import time
import random  # ← 이 줄이 반드시 필요!
import requests
import openai
import re
from supabase import create_client, Client
from dotenv import load_dotenv
from youtube_transcript_api import YouTubeTranscriptApi
load_dotenv()

# 환경 설정
SUPABASE_URL = "https://qkwqilxmwyethocfzofq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InFrd3FpbHhtd3lldGhvY2Z6b2ZxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTE4NzU4MDEsImV4cCI6MjA2NzQ1MTgwMX0.WqGljJzf5Jt2vY3gHjpa7gQ9JbMqaZ_u3TXM-YIc79g"
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")
openai.api_key = OPENAI_API_KEY
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

YOUTUBE_API_URL = "https://www.googleapis.com/youtube/v3"

def get_youtube_transcript_by_id(video_id: str) -> str:
    languages = ["ko", "en"]
    try:
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=languages)
        transcript_text = " ".join([entry["text"] for entry in transcript_list])
        return transcript_text
    except Exception as e:
        raise RuntimeError(f"비디오 ID '{video_id}'에 대한 자막을 찾을 수 없거나 사용할 수 없습니다. {e}")

def chunk_transcript(transcript: str, chunk_size: int = 300) -> list:
    return [transcript[i:i+chunk_size] for i in range(0, len(transcript), chunk_size)]

def save_channel_youtube_embeddings(channel_id: str, max_results: int = 100) -> str:
    openai.api_key = OPENAI_API_KEY
    new_video_ids = []
    next_page_token = ""
    tried_video_ids = set()

    print(f"[INFO] 채널ID: {channel_id} 영상 수집 시작")
    while len(new_video_ids) < max_results:
        search_url = (
            f"{YOUTUBE_API_URL}/search?part=snippet&channelId={channel_id}"
            f"&maxResults=50&order=date&type=video&key={YOUTUBE_API_KEY}"
        )
        if next_page_token:
            search_url += f"&pageToken={next_page_token}"
        try:
            resp = requests.get(search_url)
            data = resp.json()
        except Exception as e:
            print(f"[ERR] 유튜브 API 요청 실패: {e}")
            time.sleep(random.uniform(2, 5))
            continue

        page_video_ids = [item["id"]["videoId"] for item in data.get("items", [])]
        if not page_video_ids:
            break

        try:
            resp_db = supabase.table("youtube_videos").select("video_id").in_("video_id", page_video_ids).execute()
            existing_ids = set(row["video_id"] for row in resp_db.data)
        except Exception as e:
            print(f"[ERR] 기존 영상 조회 실패: {e}")
            existing_ids = set()

        for vid in page_video_ids:
            if vid not in existing_ids and vid not in new_video_ids and vid not in tried_video_ids:
                new_video_ids.append(vid)
                if len(new_video_ids) >= max_results:
                    break
            tried_video_ids.add(vid)

        next_page_token = data.get("nextPageToken")
        if not next_page_token:
            break

    if not new_video_ids:
        print("저장할 새로운 영상이 없습니다.")
        return "저장할 새로운 영상이 없습니다."

    count = 0
    for i, video_id in enumerate(new_video_ids):
        url = f"https://www.youtube.com/watch?v={video_id}"
        print(f"[DEBUG] 자막 추출 시도: {url}")
        time.sleep(random.uniform(2, 5))
        try:
            transcript = get_youtube_transcript_by_id(video_id)
            print(f"[OK] 자막 추출 성공: {video_id}")
        except Exception as e:
            print(f"[ERR] 자막 가져오기 실패: {video_id} - {e}")
            continue
        chunks = chunk_transcript(transcript, chunk_size=300)
        for chunk_idx, chunk in enumerate(chunks):
            try:
                time.sleep(1)
                embedding = openai.embeddings.create(
                    input=chunk,
                    model="text-embedding-3-small"
                ).data[0].embedding
            except Exception as e:
                print(f"[ERR] 임베딩 실패: {video_id} chunk {chunk_idx} - {e}")
                continue
            try:
                supabase.table("youtube_videos").insert({
                    "video_id": video_id,
                    "url": url,
                    "chunk_index": chunk_idx,
                    "chunk_text": chunk,
                    "embedding": embedding
                }).execute()
                print(f"[SAVE] 저장 완료: {video_id} chunk {chunk_idx}")
                count += 1
            except Exception as e:
                print(f"[ERR] 저장 실패: {video_id} chunk {chunk_idx} - {e}")
                continue

    return f"총 {count}개 자막 청크가 저장되었습니다."

# %%
# 사용 예시
channel_id = "UCg-p3lQIqmhh7gHpyaOmOiQ"
result = save_channel_youtube_embeddings(channel_id, max_results=100)
print(result)
# Out:
# [INFO] 채널ID: UCg-p3lQIqmhh7gHpyaOmOiQ 영상 수집 시작
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=6-_MZENrB24
# [OK] 자막 추출 성공: 6-_MZENrB24
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 0
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 1
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 2
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 3
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 4
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 5
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 6
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 7
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 8
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 9
# [SAVE] 저장 완료: 6-_MZENrB24 chunk 10
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=qSpNhKrb6dU
# [OK] 자막 추출 성공: qSpNhKrb6dU
# [SAVE] 저장 완료: qSpNhKrb6dU chunk 0
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=UgcAIwu9ySY
# [OK] 자막 추출 성공: UgcAIwu9ySY
# [SAVE] 저장 완료: UgcAIwu9ySY chunk 0
# [SAVE] 저장 완료: UgcAIwu9ySY chunk 1
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=MvNt1FFL5k0
# [OK] 자막 추출 성공: MvNt1FFL5k0
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 0
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 1
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 2
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 3
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 4
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 5
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 6
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 7
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 8
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 9
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 10
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 11
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 12
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 13
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 14
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 15
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 16
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 17
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 18
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 19
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 20
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 21
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 22
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 23
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 24
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 25
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 26
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 27
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 28
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 29
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 30
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 31
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 32
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 33
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 34
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 35
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 36
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 37
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 38
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 39
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 40
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 41
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 42
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 43
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 44
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 45
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 46
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 47
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 48
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 49
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 50
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 51
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 52
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 53
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 54
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 55
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 56
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 57
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 58
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 59
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 60
# [SAVE] 저장 완료: MvNt1FFL5k0 chunk 61
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=2yYe9mPcE2s
# [OK] 자막 추출 성공: 2yYe9mPcE2s
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 0
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 1
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 2
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 3
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 4
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 5
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 6
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 7
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 8
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 9
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 10
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 11
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 12
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 13
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 14
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 15
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 16
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 17
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 18
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 19
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 20
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 21
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 22
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 23
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 24
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 25
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 26
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 27
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 28
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 29
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 30
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 31
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 32
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 33
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 34
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 35
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 36
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 37
# [SAVE] 저장 완료: 2yYe9mPcE2s chunk 38
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=oaxEsnhY5NA
# [OK] 자막 추출 성공: oaxEsnhY5NA
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 0
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 1
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 2
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 3
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 4
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 5
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 6
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 7
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 8
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 9
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 10
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 11
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 12
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 13
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 14
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 15
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 16
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 17
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 18
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 19
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 20
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 21
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 22
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 23
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 24
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 25
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 26
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 27
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 28
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 29
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 30
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 31
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 32
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 33
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 34
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 35
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 36
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 37
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 38
# [SAVE] 저장 완료: oaxEsnhY5NA chunk 39
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=U7ixYeqBy9U
# [OK] 자막 추출 성공: U7ixYeqBy9U
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 0
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 1
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 2
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 3
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 4
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 5
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 6
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 7
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 8
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 9
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 10
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 11
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 12
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 13
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 14
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 15
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 16
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 17
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 18
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 19
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 20
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 21
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 22
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 23
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 24
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 25
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 26
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 27
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 28
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 29
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 30
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 31
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 32
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 33
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 34
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 35
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 36
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 37
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 38
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 39
# [SAVE] 저장 완료: U7ixYeqBy9U chunk 40
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=X4K4y2HsTLA
# [OK] 자막 추출 성공: X4K4y2HsTLA
# [SAVE] 저장 완료: X4K4y2HsTLA chunk 0
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=fhgTFMsnX5g
# [OK] 자막 추출 성공: fhgTFMsnX5g
# [SAVE] 저장 완료: fhgTFMsnX5g chunk 0
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=wtveNdqk7-k
# [OK] 자막 추출 성공: wtveNdqk7-k
# [SAVE] 저장 완료: wtveNdqk7-k chunk 0
# [SAVE] 저장 완료: wtveNdqk7-k chunk 1
# [SAVE] 저장 완료: wtveNdqk7-k chunk 2
# [SAVE] 저장 완료: wtveNdqk7-k chunk 3
# [SAVE] 저장 완료: wtveNdqk7-k chunk 4
# [SAVE] 저장 완료: wtveNdqk7-k chunk 5
# [SAVE] 저장 완료: wtveNdqk7-k chunk 6
# [SAVE] 저장 완료: wtveNdqk7-k chunk 7
# [SAVE] 저장 완료: wtveNdqk7-k chunk 8
# [SAVE] 저장 완료: wtveNdqk7-k chunk 9
# [SAVE] 저장 완료: wtveNdqk7-k chunk 10
# [SAVE] 저장 완료: wtveNdqk7-k chunk 11
# [SAVE] 저장 완료: wtveNdqk7-k chunk 12
# [SAVE] 저장 완료: wtveNdqk7-k chunk 13
# [SAVE] 저장 완료: wtveNdqk7-k chunk 14
# [SAVE] 저장 완료: wtveNdqk7-k chunk 15
# [SAVE] 저장 완료: wtveNdqk7-k chunk 16
# [SAVE] 저장 완료: wtveNdqk7-k chunk 17
# [SAVE] 저장 완료: wtveNdqk7-k chunk 18
# [SAVE] 저장 완료: wtveNdqk7-k chunk 19
# [SAVE] 저장 완료: wtveNdqk7-k chunk 20
# [SAVE] 저장 완료: wtveNdqk7-k chunk 21
# [SAVE] 저장 완료: wtveNdqk7-k chunk 22
# [SAVE] 저장 완료: wtveNdqk7-k chunk 23
# [SAVE] 저장 완료: wtveNdqk7-k chunk 24
# [SAVE] 저장 완료: wtveNdqk7-k chunk 25
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=qxBU4678_LI
# [OK] 자막 추출 성공: qxBU4678_LI
# [SAVE] 저장 완료: qxBU4678_LI chunk 0
# [SAVE] 저장 완료: qxBU4678_LI chunk 1
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=qAlsCIRQ24k
# [OK] 자막 추출 성공: qAlsCIRQ24k
# [SAVE] 저장 완료: qAlsCIRQ24k chunk 0
# [SAVE] 저장 완료: qAlsCIRQ24k chunk 1
# [SAVE] 저장 완료: qAlsCIRQ24k chunk 2
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=PJorf5_rdsg
# [OK] 자막 추출 성공: PJorf5_rdsg
# [SAVE] 저장 완료: PJorf5_rdsg chunk 0
# [SAVE] 저장 완료: PJorf5_rdsg chunk 1
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=3RDGsU8FT-I
# [OK] 자막 추출 성공: 3RDGsU8FT-I
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 0
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 1
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 2
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 3
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 4
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 5
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 6
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 7
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 8
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 9
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 10
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 11
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 12
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 13
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 14
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 15
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 16
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 17
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 18
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 19
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 20
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 21
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 22
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 23
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 24
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 25
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 26
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 27
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 28
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 29
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 30
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 31
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 32
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 33
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 34
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 35
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 36
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 37
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 38
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 39
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 40
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 41
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 42
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 43
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 44
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 45
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 46
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 47
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 48
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 49
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 50
# [SAVE] 저장 완료: 3RDGsU8FT-I chunk 51
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=cEiQ41TkKv8
# [OK] 자막 추출 성공: cEiQ41TkKv8
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 0
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 1
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 2
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 3
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 4
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 5
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 6
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 7
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 8
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 9
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 10
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 11
# [SAVE] 저장 완료: cEiQ41TkKv8 chunk 12
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=HQ5Af0gfa8Q
# [OK] 자막 추출 성공: HQ5Af0gfa8Q
# [SAVE] 저장 완료: HQ5Af0gfa8Q chunk 0
# [SAVE] 저장 완료: HQ5Af0gfa8Q chunk 1
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=hYJVbQxZCsU
# [OK] 자막 추출 성공: hYJVbQxZCsU
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 0
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 1
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 2
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 3
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 4
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 5
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 6
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 7
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 8
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 9
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 10
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 11
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 12
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 13
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 14
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 15
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 16
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 17
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 18
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 19
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 20
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 21
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 22
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 23
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 24
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 25
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 26
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 27
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 28
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 29
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 30
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 31
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 32
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 33
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 34
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 35
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 36
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 37
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 38
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 39
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 40
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 41
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 42
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 43
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 44
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 45
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 46
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 47
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 48
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 49
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 50
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 51
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 52
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 53
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 54
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 55
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 56
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 57
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 58
# [SAVE] 저장 완료: hYJVbQxZCsU chunk 59
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=U8vYYXuRzJ4
# [OK] 자막 추출 성공: U8vYYXuRzJ4
# [SAVE] 저장 완료: U8vYYXuRzJ4 chunk 0
# [SAVE] 저장 완료: U8vYYXuRzJ4 chunk 1
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=eByt08gBDGs
# [OK] 자막 추출 성공: eByt08gBDGs
# [SAVE] 저장 완료: eByt08gBDGs chunk 0
# [SAVE] 저장 완료: eByt08gBDGs chunk 1
# [SAVE] 저장 완료: eByt08gBDGs chunk 2
# [SAVE] 저장 완료: eByt08gBDGs chunk 3
# [SAVE] 저장 완료: eByt08gBDGs chunk 4
# [SAVE] 저장 완료: eByt08gBDGs chunk 5
# [SAVE] 저장 완료: eByt08gBDGs chunk 6
# [SAVE] 저장 완료: eByt08gBDGs chunk 7
# [SAVE] 저장 완료: eByt08gBDGs chunk 8
# [SAVE] 저장 완료: eByt08gBDGs chunk 9
# [SAVE] 저장 완료: eByt08gBDGs chunk 10
# [SAVE] 저장 완료: eByt08gBDGs chunk 11
# [SAVE] 저장 완료: eByt08gBDGs chunk 12
# [SAVE] 저장 완료: eByt08gBDGs chunk 13
# [SAVE] 저장 완료: eByt08gBDGs chunk 14
# [SAVE] 저장 완료: eByt08gBDGs chunk 15
# [SAVE] 저장 완료: eByt08gBDGs chunk 16
# [SAVE] 저장 완료: eByt08gBDGs chunk 17
# [SAVE] 저장 완료: eByt08gBDGs chunk 18
# [SAVE] 저장 완료: eByt08gBDGs chunk 19
# [SAVE] 저장 완료: eByt08gBDGs chunk 20
# [SAVE] 저장 완료: eByt08gBDGs chunk 21
# [SAVE] 저장 완료: eByt08gBDGs chunk 22
# [SAVE] 저장 완료: eByt08gBDGs chunk 23
# [SAVE] 저장 완료: eByt08gBDGs chunk 24
# [SAVE] 저장 완료: eByt08gBDGs chunk 25
# [SAVE] 저장 완료: eByt08gBDGs chunk 26
# [SAVE] 저장 완료: eByt08gBDGs chunk 27
# [SAVE] 저장 완료: eByt08gBDGs chunk 28
# [SAVE] 저장 완료: eByt08gBDGs chunk 29
# [SAVE] 저장 완료: eByt08gBDGs chunk 30
# [SAVE] 저장 완료: eByt08gBDGs chunk 31
# [SAVE] 저장 완료: eByt08gBDGs chunk 32
# [SAVE] 저장 완료: eByt08gBDGs chunk 33
# [SAVE] 저장 완료: eByt08gBDGs chunk 34
# [SAVE] 저장 완료: eByt08gBDGs chunk 35
# [SAVE] 저장 완료: eByt08gBDGs chunk 36
# [SAVE] 저장 완료: eByt08gBDGs chunk 37
# [SAVE] 저장 완료: eByt08gBDGs chunk 38
# [SAVE] 저장 완료: eByt08gBDGs chunk 39
# [SAVE] 저장 완료: eByt08gBDGs chunk 40
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=EocrQ-eClgo
# [OK] 자막 추출 성공: EocrQ-eClgo
# [SAVE] 저장 완료: EocrQ-eClgo chunk 0
# [SAVE] 저장 완료: EocrQ-eClgo chunk 1
# [SAVE] 저장 완료: EocrQ-eClgo chunk 2
# [SAVE] 저장 완료: EocrQ-eClgo chunk 3
# [SAVE] 저장 완료: EocrQ-eClgo chunk 4
# [SAVE] 저장 완료: EocrQ-eClgo chunk 5
# [SAVE] 저장 완료: EocrQ-eClgo chunk 6
# [SAVE] 저장 완료: EocrQ-eClgo chunk 7
# [SAVE] 저장 완료: EocrQ-eClgo chunk 8
# [SAVE] 저장 완료: EocrQ-eClgo chunk 9
# [SAVE] 저장 완료: EocrQ-eClgo chunk 10
# [SAVE] 저장 완료: EocrQ-eClgo chunk 11
# [SAVE] 저장 완료: EocrQ-eClgo chunk 12
# [SAVE] 저장 완료: EocrQ-eClgo chunk 13
# [SAVE] 저장 완료: EocrQ-eClgo chunk 14
# [SAVE] 저장 완료: EocrQ-eClgo chunk 15
# [SAVE] 저장 완료: EocrQ-eClgo chunk 16
# [SAVE] 저장 완료: EocrQ-eClgo chunk 17
# [SAVE] 저장 완료: EocrQ-eClgo chunk 18
# [SAVE] 저장 완료: EocrQ-eClgo chunk 19
# [SAVE] 저장 완료: EocrQ-eClgo chunk 20
# [SAVE] 저장 완료: EocrQ-eClgo chunk 21
# [SAVE] 저장 완료: EocrQ-eClgo chunk 22
# [SAVE] 저장 완료: EocrQ-eClgo chunk 23
# [SAVE] 저장 완료: EocrQ-eClgo chunk 24
# [SAVE] 저장 완료: EocrQ-eClgo chunk 25
# [SAVE] 저장 완료: EocrQ-eClgo chunk 26
# [SAVE] 저장 완료: EocrQ-eClgo chunk 27
# [SAVE] 저장 완료: EocrQ-eClgo chunk 28
# [SAVE] 저장 완료: EocrQ-eClgo chunk 29
# [SAVE] 저장 완료: EocrQ-eClgo chunk 30
# [SAVE] 저장 완료: EocrQ-eClgo chunk 31
# [SAVE] 저장 완료: EocrQ-eClgo chunk 32
# [SAVE] 저장 완료: EocrQ-eClgo chunk 33
# [SAVE] 저장 완료: EocrQ-eClgo chunk 34
# [SAVE] 저장 완료: EocrQ-eClgo chunk 35
# [SAVE] 저장 완료: EocrQ-eClgo chunk 36
# [SAVE] 저장 완료: EocrQ-eClgo chunk 37
# [SAVE] 저장 완료: EocrQ-eClgo chunk 38
# [SAVE] 저장 완료: EocrQ-eClgo chunk 39
# [SAVE] 저장 완료: EocrQ-eClgo chunk 40
# [SAVE] 저장 완료: EocrQ-eClgo chunk 41
# [SAVE] 저장 완료: EocrQ-eClgo chunk 42
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=DlCdZUF0xE0
# [OK] 자막 추출 성공: DlCdZUF0xE0
# [SAVE] 저장 완료: DlCdZUF0xE0 chunk 0
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=d9Zn19CSVGI
# [OK] 자막 추출 성공: d9Zn19CSVGI
# [SAVE] 저장 완료: d9Zn19CSVGI chunk 0
# [SAVE] 저장 완료: d9Zn19CSVGI chunk 1
# [SAVE] 저장 완료: d9Zn19CSVGI chunk 2
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=OSnkYKihmxQ
# [OK] 자막 추출 성공: OSnkYKihmxQ
# [SAVE] 저장 완료: OSnkYKihmxQ chunk 0
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=nmlY-oRMjuo
# [OK] 자막 추출 성공: nmlY-oRMjuo
# [SAVE] 저장 완료: nmlY-oRMjuo chunk 0
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=QOF90LFb-lI
# [OK] 자막 추출 성공: QOF90LFb-lI
# [SAVE] 저장 완료: QOF90LFb-lI chunk 0
# [SAVE] 저장 완료: QOF90LFb-lI chunk 1
# [SAVE] 저장 완료: QOF90LFb-lI chunk 2
# [SAVE] 저장 완료: QOF90LFb-lI chunk 3
# [SAVE] 저장 완료: QOF90LFb-lI chunk 4
# [SAVE] 저장 완료: QOF90LFb-lI chunk 5
# [SAVE] 저장 완료: QOF90LFb-lI chunk 6
# [SAVE] 저장 완료: QOF90LFb-lI chunk 7
# [SAVE] 저장 완료: QOF90LFb-lI chunk 8
# [SAVE] 저장 완료: QOF90LFb-lI chunk 9
# [SAVE] 저장 완료: QOF90LFb-lI chunk 10
# [SAVE] 저장 완료: QOF90LFb-lI chunk 11
# [SAVE] 저장 완료: QOF90LFb-lI chunk 12
# [SAVE] 저장 완료: QOF90LFb-lI chunk 13
# [SAVE] 저장 완료: QOF90LFb-lI chunk 14
# [SAVE] 저장 완료: QOF90LFb-lI chunk 15
# [SAVE] 저장 완료: QOF90LFb-lI chunk 16
# [SAVE] 저장 완료: QOF90LFb-lI chunk 17
# [SAVE] 저장 완료: QOF90LFb-lI chunk 18
# [SAVE] 저장 완료: QOF90LFb-lI chunk 19
# [SAVE] 저장 완료: QOF90LFb-lI chunk 20
# [SAVE] 저장 완료: QOF90LFb-lI chunk 21
# [SAVE] 저장 완료: QOF90LFb-lI chunk 22
# [SAVE] 저장 완료: QOF90LFb-lI chunk 23
# [SAVE] 저장 완료: QOF90LFb-lI chunk 24
# [SAVE] 저장 완료: QOF90LFb-lI chunk 25
# [SAVE] 저장 완료: QOF90LFb-lI chunk 26
# [SAVE] 저장 완료: QOF90LFb-lI chunk 27
# [SAVE] 저장 완료: QOF90LFb-lI chunk 28
# [SAVE] 저장 완료: QOF90LFb-lI chunk 29
# [SAVE] 저장 완료: QOF90LFb-lI chunk 30
# [SAVE] 저장 완료: QOF90LFb-lI chunk 31
# [SAVE] 저장 완료: QOF90LFb-lI chunk 32
# [SAVE] 저장 완료: QOF90LFb-lI chunk 33
# [SAVE] 저장 완료: QOF90LFb-lI chunk 34
# [SAVE] 저장 완료: QOF90LFb-lI chunk 35
# [SAVE] 저장 완료: QOF90LFb-lI chunk 36
# [SAVE] 저장 완료: QOF90LFb-lI chunk 37
# [SAVE] 저장 완료: QOF90LFb-lI chunk 38
# [SAVE] 저장 완료: QOF90LFb-lI chunk 39
# [SAVE] 저장 완료: QOF90LFb-lI chunk 40
# [SAVE] 저장 완료: QOF90LFb-lI chunk 41
# [SAVE] 저장 완료: QOF90LFb-lI chunk 42
# [SAVE] 저장 완료: QOF90LFb-lI chunk 43
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=vuwV0NenbIg
# [OK] 자막 추출 성공: vuwV0NenbIg
# [SAVE] 저장 완료: vuwV0NenbIg chunk 0
# [SAVE] 저장 완료: vuwV0NenbIg chunk 1
# [SAVE] 저장 완료: vuwV0NenbIg chunk 2
# [SAVE] 저장 완료: vuwV0NenbIg chunk 3
# [SAVE] 저장 완료: vuwV0NenbIg chunk 4
# [SAVE] 저장 완료: vuwV0NenbIg chunk 5
# [SAVE] 저장 완료: vuwV0NenbIg chunk 6
# [SAVE] 저장 완료: vuwV0NenbIg chunk 7
# [SAVE] 저장 완료: vuwV0NenbIg chunk 8
# [SAVE] 저장 완료: vuwV0NenbIg chunk 9
# [SAVE] 저장 완료: vuwV0NenbIg chunk 10
# [SAVE] 저장 완료: vuwV0NenbIg chunk 11
# [SAVE] 저장 완료: vuwV0NenbIg chunk 12
# [SAVE] 저장 완료: vuwV0NenbIg chunk 13
# [SAVE] 저장 완료: vuwV0NenbIg chunk 14
# [SAVE] 저장 완료: vuwV0NenbIg chunk 15
# [SAVE] 저장 완료: vuwV0NenbIg chunk 16
# [SAVE] 저장 완료: vuwV0NenbIg chunk 17
# [SAVE] 저장 완료: vuwV0NenbIg chunk 18
# [SAVE] 저장 완료: vuwV0NenbIg chunk 19
# [SAVE] 저장 완료: vuwV0NenbIg chunk 20
# [SAVE] 저장 완료: vuwV0NenbIg chunk 21
# [SAVE] 저장 완료: vuwV0NenbIg chunk 22
# [SAVE] 저장 완료: vuwV0NenbIg chunk 23
# [SAVE] 저장 완료: vuwV0NenbIg chunk 24
# [SAVE] 저장 완료: vuwV0NenbIg chunk 25
# [SAVE] 저장 완료: vuwV0NenbIg chunk 26
# [SAVE] 저장 완료: vuwV0NenbIg chunk 27
# [SAVE] 저장 완료: vuwV0NenbIg chunk 28
# [SAVE] 저장 완료: vuwV0NenbIg chunk 29
# [SAVE] 저장 완료: vuwV0NenbIg chunk 30
# [SAVE] 저장 완료: vuwV0NenbIg chunk 31
# [SAVE] 저장 완료: vuwV0NenbIg chunk 32
# [SAVE] 저장 완료: vuwV0NenbIg chunk 33
# [SAVE] 저장 완료: vuwV0NenbIg chunk 34
# [SAVE] 저장 완료: vuwV0NenbIg chunk 35
# [SAVE] 저장 완료: vuwV0NenbIg chunk 36
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=oHf5EtioGn8
# [OK] 자막 추출 성공: oHf5EtioGn8
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 0
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 1
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 2
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 3
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 4
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 5
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 6
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 7
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 8
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 9
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 10
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 11
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 12
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 13
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 14
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 15
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 16
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 17
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 18
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 19
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 20
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 21
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 22
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 23
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 24
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 25
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 26
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 27
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 28
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 29
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 30
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 31
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 32
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 33
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 34
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 35
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 36
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 37
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 38
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 39
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 40
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 41
# [SAVE] 저장 완료: oHf5EtioGn8 chunk 42
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=xxE5LhiH6CI
# [OK] 자막 추출 성공: xxE5LhiH6CI
# [SAVE] 저장 완료: xxE5LhiH6CI chunk 0
# [SAVE] 저장 완료: xxE5LhiH6CI chunk 1
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=3EL_fOarLxk
# [OK] 자막 추출 성공: 3EL_fOarLxk
# [SAVE] 저장 완료: 3EL_fOarLxk chunk 0
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=8zZRTR3mel8
# [OK] 자막 추출 성공: 8zZRTR3mel8
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 0
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 1
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 2
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 3
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 4
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 5
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 6
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 7
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 8
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 9
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 10
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 11
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 12
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 13
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 14
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 15
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 16
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 17
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 18
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 19
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 20
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 21
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 22
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 23
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 24
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 25
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 26
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 27
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 28
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 29
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 30
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 31
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 32
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 33
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 34
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 35
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 36
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 37
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 38
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 39
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 40
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 41
# [SAVE] 저장 완료: 8zZRTR3mel8 chunk 42
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=XZJNOmuY3Ko
# [OK] 자막 추출 성공: XZJNOmuY3Ko
# [SAVE] 저장 완료: XZJNOmuY3Ko chunk 0
# [SAVE] 저장 완료: XZJNOmuY3Ko chunk 1
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=bw3AxVFE4Bg
# [OK] 자막 추출 성공: bw3AxVFE4Bg
# [SAVE] 저장 완료: bw3AxVFE4Bg chunk 0
# [SAVE] 저장 완료: bw3AxVFE4Bg chunk 1
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=xYL_cvGBaWw
# [OK] 자막 추출 성공: xYL_cvGBaWw
# [SAVE] 저장 완료: xYL_cvGBaWw chunk 0
# [SAVE] 저장 완료: xYL_cvGBaWw chunk 1
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=YAi9MSi8UzA
# [OK] 자막 추출 성공: YAi9MSi8UzA
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 0
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 1
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 2
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 3
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 4
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 5
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 6
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 7
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 8
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 9
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 10
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 11
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 12
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 13
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 14
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 15
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 16
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 17
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 18
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 19
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 20
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 21
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 22
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 23
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 24
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 25
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 26
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 27
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 28
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 29
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 30
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 31
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 32
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 33
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 34
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 35
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 36
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 37
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 38
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 39
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 40
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 41
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 42
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 43
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 44
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 45
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 46
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 47
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 48
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 49
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 50
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 51
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 52
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 53
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 54
# [SAVE] 저장 완료: YAi9MSi8UzA chunk 55
# [DEBUG] 자막 추출 시도: https://www.youtube.com/watch?v=qx99o1t5tZQ
# [OK] 자막 추출 성공: qx99o1t5tZQ
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # 사용 예시
#       2 channel_id = "UCg-p3lQIqmhh7gHpyaOmOiQ"
# ----> 3 result = save_channel_youtube_embeddings(channel_id, max_results=100)
#       4 print(result)
#
# Cell In[1], line 96, in save_channel_youtube_embeddings(channel_id, max_results)
#      94 for chunk_idx, chunk in enumerate(chunks):
#      95     try:
# ---> 96         time.sleep(1)
#      97         embedding = openai.embeddings.create(
#      98             input=chunk,
#      99             model="text-embedding-3-small"
#     100         ).data[0].embedding
#     101     except Exception as e:
#
# KeyboardInterrupt:

# %%
def search_youtube_videos(query: str) :
    """유튜브에서 특정 키워드로 동영상을 검색하고 세부 정보를 가져옵니다"""
    try:
        # 1. 동영상 검색
        max_results: int = 20
        search_url = f"{YOUTUBE_API_URL}/search?part=snippet&q={requests.utils.quote(query)}&type=video&maxResults={max_results}&key={YOUTUBE_API_KEY}"
        print(f"Searching YouTube with URL: {search_url}")

        search_response = requests.get(search_url)
        search_data = search_response.json()
        video_ids = [item['id']['videoId'] for item in search_data.get('items', [])]

        if not video_ids:
            print("No videos found for the query.")
            return []

        video_details_url = f"{YOUTUBE_API_URL}/videos?part=snippet,statistics&id={','.join(video_ids)}&key={YOUTUBE_API_KEY}"
        print(f"영상 정보 가져오는 중: {video_details_url}")
        details_response = requests.get(video_details_url)
        details_response.raise_for_status()
        details_data = details_response.json()

        videos = []
        for item in details_data.get('items', []):
            snippet = item.get('snippet', {})
            statistics = item.get('statistics', {})
            thumbnails = snippet.get('thumbnails', {})
            high_thumbnail = thumbnails.get('high', {}) 
            view_count = statistics.get('viewCount')
            like_count = statistics.get('likeCount')

            video_card = {
                "title": snippet.get('title', 'N/A'),
                "publishedDate": snippet.get('publishedAt', ''),
                "channelName": snippet.get('channelTitle', 'N/A'),
                "channelId": snippet.get('channelId', ''),
                "thumbnailUrl": high_thumbnail.get('url', ''),
                "viewCount": int(view_count) if view_count is not None else None,
                "likeCount": int(like_count) if like_count is not None else None,
                "url": f"https://www.youtube.com/watch?v={item.get('id', '')}",
            }
            videos.append(video_card)

        if not videos:
            print("No video details could be fetched.")
            return []

        return videos

    except Exception as e:
        print(f"Error: {e}")
        return []

# %%
videos = search_youtube_videos("AI Agents")
for video in videos:
    pprint(video)
# Out:
# Searching YouTube with URL: https://www.googleapis.com/youtube/v3/search?part=snippet&q=AI%20Agents&type=video&maxResults=20&key=AIzaSyAOz5efF0LiQ3txpyOO1qd8LLW49v_5gC8
# 영상 정보 가져오는 중: https://www.googleapis.com/youtube/v3/videos?part=snippet,statistics&id=O2gerCxEXvc,geR9PeCuHK4,F8NKVhkZZWI,FwOTs4UxQS4,hLJTcVHW8_I,eHEHE2fpnWQ,ShhVdkgzqUI,BF2k_fKuCVM,qU3fmidNbJE,HISRUrJsD08,fXizBc03D7E,gGy-JDcOwlI,77NpesUmr5Q,wazHMMaiDEA,LP5OCa20Zpg,2aC2ly7vKtM,_4jVeVkUOzs,Ctpo_gsGQJs,wkuwMqrOXFE,WfIJhS_1xIk&key=AIzaSyAOz5efF0LiQ3txpyOO1qd8LLW49v_5gC8
# {'channelId': 'UCh9nVJoWXmFb7sLApWGcLPQ',
#  'channelName': 'codebasics',
#  'likeCount': 542,
#  'publishedDate': '2025-06-30T16:10:56Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/O2gerCxEXvc/hqdefault.jpg',
#  'title': 'Generative ai vs AI agents vs Agentic AI',
#  'url': 'https://www.youtube.com/watch?v=O2gerCxEXvc',
#  'viewCount': 16387}
# {'channelId': 'UCWZwfV3ICOt3uEPpW6hYK4g',
#  'channelName': 'AI Foundations',
#  'likeCount': 977,
#  'publishedDate': '2025-06-30T14:47:57Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/geR9PeCuHK4/hqdefault.jpg',
#  'title': 'How to Build AI Agents with n8n in 2025! (Full Course)',
#  'url': 'https://www.youtube.com/watch?v=geR9PeCuHK4',
#  'viewCount': 17311}
# {'channelId': 'UCKWaEZ-_VweaEx1j62do_vQ',
#  'channelName': 'IBM Technology',
#  'likeCount': 28543,
#  'publishedDate': '2024-07-15T10:00:13Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/F8NKVhkZZWI/hqdefault.jpg',
#  'title': 'What are AI Agents?',
#  'url': 'https://www.youtube.com/watch?v=F8NKVhkZZWI',
#  'viewCount': 1516307}
# {'channelId': 'UCwAnu01qlnVg1Ai2AbtTMaA',
#  'channelName': 'Jeff Su',
#  'likeCount': 56862,
#  'publishedDate': '2025-04-08T13:00:28Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/FwOTs4UxQS4/hqdefault.jpg',
#  'title': 'AI Agents, Clearly Explained',
#  'url': 'https://www.youtube.com/watch?v=FwOTs4UxQS4',
#  'viewCount': 1970416}
# {'channelId': 'UCismEm75ASmEIXU-UpdFYnQ',
#  'channelName': 'AI Alfie ',
#  'likeCount': 6325,
#  'publishedDate': '2024-04-29T23:55:25Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/hLJTcVHW8_I/hqdefault.jpg',
#  'title': 'AI Agents Explained: A Comprehensive Guide for Beginners',
#  'url': 'https://www.youtube.com/watch?v=hLJTcVHW8_I',
#  'viewCount': 350231}
# {'channelId': 'UCZgt6AzoyjslHTC9dz0UoTw',
#  'channelName': 'ByteByteGo',
#  'likeCount': 4123,
#  'publishedDate': '2025-03-19T15:30:14Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/eHEHE2fpnWQ/hqdefault.jpg',
#  'title': 'What Are AI Agents Really About?',
#  'url': 'https://www.youtube.com/watch?v=eHEHE2fpnWQ',
#  'viewCount': 168257}
# {'channelId': 'UC5l7RouTQ60oUjLjt1Nh-UQ',
#  'channelName': 'AI Revolution',
#  'likeCount': 908,
#  'publishedDate': '2025-06-29T22:58:17Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/ShhVdkgzqUI/hqdefault.jpg',
#  'title': 'Self Prompting AI Agent About to Break the Internet: Fully '
#           'Autonomous AI Workflow',
#  'url': 'https://www.youtube.com/watch?v=ShhVdkgzqUI',
#  'viewCount': 42097}
# {'channelId': 'UCwAnu01qlnVg1Ai2AbtTMaA',
#  'channelName': 'Jeff Su',
#  'likeCount': 1986,
#  'publishedDate': '2025-05-08T13:18:56Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/BF2k_fKuCVM/hqdefault.jpg',
#  'title': 'AI Agents explained in 3 steps',
#  'url': 'https://www.youtube.com/watch?v=BF2k_fKuCVM',
#  'viewCount': 57200}
# {'channelId': 'UC2UXDak6o7rBm23k3Vv5dww',
#  'channelName': 'Tina Huang',
#  'likeCount': 42865,
#  'publishedDate': '2025-02-16T14:33:21Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/qU3fmidNbJE/hqdefault.jpg',
#  'title': 'AI Agents Fundamentals In 21 Minutes',
#  'url': 'https://www.youtube.com/watch?v=qU3fmidNbJE',
#  'viewCount': 1179313}
# {'channelId': 'UCY6N8zZhs2V7gNTUxPuKWoQ',
#  'channelName': 'Ishan Sharma',
#  'likeCount': 6719,
#  'publishedDate': '2025-03-07T14:03:13Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/HISRUrJsD08/hqdefault.jpg',
#  'title': 'AI Agents EXPLAINED In 13 Minutes.',
#  'url': 'https://www.youtube.com/watch?v=HISRUrJsD08',
#  'viewCount': 189458}
# {'channelId': 'UCKWaEZ-_VweaEx1j62do_vQ',
#  'channelName': 'IBM Technology',
#  'likeCount': 3550,
#  'publishedDate': '2025-04-28T11:01:07Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/fXizBc03D7E/hqdefault.jpg',
#  'title': '5 Types of AI Agents: Autonomous Functions & Real-World '
#           'Applications',
#  'url': 'https://www.youtube.com/watch?v=fXizBc03D7E',
#  'viewCount': 167334}
# {'channelId': 'UCL5pyu8ZlKGqrmMwZ-BGimQ',
#  'channelName': 'Amine DALY',
#  'likeCount': 939,
#  'publishedDate': '2025-04-15T23:37:24Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/gGy-JDcOwlI/hqdefault.jpg',
#  'title': 'How LangChain Works to Create AI Agents | Explained Simply '
#           '#LangChain #aiagent #aiframework',
#  'url': 'https://www.youtube.com/watch?v=gGy-JDcOwlI',
#  'viewCount': 21057}
# {'channelId': 'UClYy-MQuDXPf3gI-bsLcuEw',
#  'channelName': 'Tom Shaw',
#  'likeCount': 749,
#  'publishedDate': '2025-03-05T12:30:14Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/77NpesUmr5Q/hqdefault.jpg',
#  'title': 'Building AI Agents for my business! 🤖 #coding #programming #ai',
#  'url': 'https://www.youtube.com/watch?v=77NpesUmr5Q',
#  'viewCount': 18879}
# {'channelId': 'UCooW1kDrMUb1EORhDbmciOw',
#  'channelName': 'Vendasta',
#  'likeCount': 28183,
#  'publishedDate': '2024-09-25T16:26:15Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/wazHMMaiDEA/hqdefault.jpg',
#  'title': "AI Agents Explained Like You're 5 (Seriously, Easiest Explanation "
#           'Ever!)',
#  'url': 'https://www.youtube.com/watch?v=wazHMMaiDEA',
#  'viewCount': 778422}
# {'channelId': 'UCrDwWp7EBBv4NwvScIpBDOA',
#  'channelName': 'Anthropic',
#  'likeCount': 10012,
#  'publishedDate': '2025-02-13T12:21:22Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/LP5OCa20Zpg/hqdefault.jpg',
#  'title': 'Tips for building AI agents',
#  'url': 'https://www.youtube.com/watch?v=LP5OCa20Zpg',
#  'viewCount': 433161}
# {'channelId': 'UC2ojq-nuP8ceeHqiroeKhBA',
#  'channelName': 'Nate Herk | AI Automation',
#  'likeCount': 12668,
#  'publishedDate': '2025-02-03T05:09:21Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/2aC2ly7vKtM/hqdefault.jpg',
#  'title': 'I Built the Ultimate Team of Agents in n8n  #artificialintelligence '
#           '#n8n #agentgpt  #techtok #coding',
#  'url': 'https://www.youtube.com/watch?v=2aC2ly7vKtM',
#  'viewCount': 300130}
# {'channelId': 'UCnIEygpkXQB5YCm2w7NDw2A',
#  'channelName': 'All-In Podcast Clips',
#  'likeCount': 377,
#  'publishedDate': '2024-05-13T00:19:37Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/_4jVeVkUOzs/hqdefault.jpg',
#  'title': 'Sam Altman on the Two Outcomes for AI Agents',
#  'url': 'https://www.youtube.com/watch?v=_4jVeVkUOzs',
#  'viewCount': 18998}
# {'channelId': 'UCY0isIThHOkcIOTB7WWVK6A',
#  'channelName': 'digitalSamaritan',
#  'likeCount': 366,
#  'publishedDate': '2025-04-25T17:12:14Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/Ctpo_gsGQJs/hqdefault.jpg',
#  'title': 'Free course to build AI Agents #aitools #aiagents',
#  'url': 'https://www.youtube.com/watch?v=Ctpo_gsGQJs',
#  'viewCount': 11216}
# {'channelId': 'UCLZu-v9rR2rQLH6MhrXNHJg',
#  'channelName': 'Harper Carroll AI',
#  'likeCount': 2246,
#  'publishedDate': '2024-09-04T18:52:47Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/wkuwMqrOXFE/hqdefault.jpg',
#  'title': 'AI “Agents” explAIned - how are they different?',
#  'url': 'https://www.youtube.com/watch?v=wkuwMqrOXFE',
#  'viewCount': 68752}
# {'channelId': 'UCl-Zrl0QhF66lu1aGXaTbfw',
#  'channelName': 'Neil Patel',
#  'likeCount': 2235,
#  'publishedDate': '2025-03-23T17:00:33Z',
#  'thumbnailUrl': 'https://i.ytimg.com/vi/WfIJhS_1xIk/hqdefault.jpg',
#  'title': "It's easy to create AI Agents",
#  'url': 'https://www.youtube.com/watch?v=WfIJhS_1xIk',
#  'viewCount': 78481}

# %%
def get_channel_info(video_url: str) -> dict:
    """YouTube 동영상 URL로부터 채널 정보와 최근 100개의 동영상을 가져옵니다"""
    def extract_video_id(url):
        match = re.search(r"(?:v=|\/)([0-9A-Za-z_-]{11})", url)
        return match.group(1) if match else None
    def fetch_recent_videos(channel_id):
        rss_url = f"https://www.youtube.com/feeds/videos.xml?channel_id={channel_id}"
        try:
            response = requests.get(rss_url)
            if response.status_code != 200:
                return []

            root = ET.fromstring(response.text)
            ns = {'atom': 'http://www.w3.org/2005/Atom'}
            videos = []

            for entry in root.findall('.//atom:entry', ns)[:100]:  
                title = entry.find('./atom:title', ns).text
                link = entry.find('./atom:link', ns).attrib['href']
                published = entry.find('./atom:published', ns).text
                videos.append({
                    'title': title,
                    'link': link,
                    'published': published,
                    'updatedDate': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                })

            return videos
        except:
            return []

    video_id = extract_video_id(video_url)
    if not video_id:
        raise ValueError("Invalid YouTube URL")

    video_api = f"{YOUTUBE_API_URL}/videos?part=snippet,statistics&id={video_id}&key={YOUTUBE_API_KEY}"
    video_data = requests.get(video_api).json()
    if not video_data.get('items'):
        raise ValueError("No video found")

    video_info = video_data['items'][0]
    channel_id = video_info['snippet']['channelId']

    channel_api = f"{YOUTUBE_API_URL}/channels?part=snippet,statistics&id={channel_id}&key={YOUTUBE_API_KEY}"
    channel_data = requests.get(channel_api).json()['items'][0]

    return {
        'channelTitle': channel_data['snippet']['title'],
        'channelUrl': f"https://www.youtube.com/channel/{channel_id}",
        'subscriberCount': channel_data['statistics'].get('subscriberCount', '0'),
        'viewCount': channel_data['statistics'].get('viewCount', '0'),
        'videoCount': channel_data['statistics'].get('videoCount', '0'),
        'videos': fetch_recent_videos(channel_id)
    }

# %%
pprint(get_channel_info("https://www.youtube.com/watch?v=gYqs-wUKZsM")) ## openai 영상
# Out:
# {'channelTitle': 'OpenAI',
#  'channelUrl': 'https://www.youtube.com/channel/UCXZCJLdBC09xxGZ6gcdrc6A',
#  'subscriberCount': '1580000',
#  'videoCount': '302',
#  'videos': [{'link': 'https://www.youtube.com/watch?v=atXyXP3yYZ4',
#              'published': '2025-07-01T14:50:39+00:00',
#              'title': 'Inside ChatGPT, AI assistants, and building at OpenAI — '
#                       'the OpenAI Podcast Ep. 2',
#              'updatedDate': '2025-07-02 11:24:24'},
#             {'link': 'https://www.youtube.com/shorts/XGswiRpn6js',
#              'published': '2025-06-27T19:51:05+00:00',
#              'title': 'A quick guide | How to search in ChatGPT',
#              'updatedDate': '2025-07-02 11:24:24'},
#             {'link': 'https://www.youtube.com/shorts/rswUgIfj1YU',
#              'published': '2025-06-25T18:32:15+00:00',
#              'title': 'UCLA student shares how he was using ChatGPT',
#              'updatedDate': '2025-07-02 11:24:24'},
#             {'link': 'https://www.youtube.com/shorts/E0NJyUy8kc8',
#              'published': '2025-06-23T18:02:44+00:00',
#              'title': 'If ChatGPT were your wingman…',
#              'updatedDate': '2025-07-02 11:24:24'},
#             {'link': 'https://www.youtube.com/shorts/jELUAaGqjSA',
#              'published': '2025-06-18T23:21:58+00:00',
#              'title': 'The real ways college students use ChatGPT',
#              'updatedDate': '2025-07-02 11:24:24'}],
#  'viewCount': '74871343'}

# %%
import openai
from supabase import create_client, Client
import os

SUPABASE_URL="https://qkwqilxmwyethocfzofq.supabase.co"
SUPABASE_KEY="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InFrd3FpbHhtd3lldGhvY2Z6b2ZxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTE4NzU4MDEsImV4cCI6MjA2NzQ1MTgwMX0.WqGljJzf5Jt2vY3gHjpa7gQ9JbMqaZ_u3TXM-YIc79g"
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

openai.api_key = os.getenv("OPENAI_API_KEY")

def search_similar_youtube_video(query: str) -> dict:
    """검색어를 임베딩하고 Supabase RPC를 통해 가장 유사한 자막 청크(및 비디오) 정보를 반환"""
    try:
        # 1. OpenAI를 사용해 쿼리 임베딩 생성
        embedding_response = openai.embeddings.create(
            input=query,
            model="text-embedding-3-small"
        )
        embedding = embedding_response.data[0].embedding

        # 2. Supabase RPC 호출 (input_vector는 JSON 형태 리스트 그대로 넘김)
        response = supabase.rpc("match_youtube_video", {
            "input_vector": embedding
        }).execute()

        # 3. 결과 반환
        if response.data and len(response.data) > 0:
            result = response.data[0]
            return {
                "video_id": result.get("video_id"),
                "url": result.get("url"),
                "chunk_index": result.get("chunk_index"),
                "chunk_text": result.get("chunk_text"),
                "score": result.get("score", None)
            } 
        else:
            return {"error": "No similar video found."}

    except Exception as e:
        import traceback
        traceback.print_exc()
        return {"error": str(e)}

# %%
result = search_similar_youtube_video("짜파게티")
print(result)
# Out:
# {'video_id': '6-_MZENrB24', 'url': 'https://www.youtube.com/watch?v=6-_MZENrB24', 'chunk_index': 2, 'chunk_text': '막으로 고스트 페퍼 라면 짜파게티네. 짜파게티라고 생각하고 먹으면 짜파게티야. 오 좋아. 많이 먹었어. 어때? 괜찮나 본데? 생각보다 와 어떡해 와 와 근데 이게 덤점 오네어 아 오 이겨 냈어 캡사이신 매운 맛이랑 느낌이 달라 캡사이신은 혀를 막 자르고 싶은 느낌이 있잖아 근데 이거는 혀를 그 무슨 느낌인지 알겠죠 어 이게 나 내가 보기 이게 더 맵지 아니 이미 이거 먹어서 감각이 SM타운에서 공연하셨잖아요. 런던에서 공연 처음 하는 건 기억나세요? 아마 런던의 첫 케팝 페스티벌이었던 거 같은데 2012년 맞아요. 그때 생각하니가 ', 'score': 0.390624034684189}
